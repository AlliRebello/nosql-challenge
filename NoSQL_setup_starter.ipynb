# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `YOUR IMPORT TEXT HERE`

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'classdb', 'config', 'epa', 'fruits_db', 'gardenDB', 'local', 'met', 'petsitly_marketing', 'uk_food', 'uk_fook']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
print (db.list_collection_names())
# Out:
# ['establishments']

# %%
# review the collections in our new database
establishments = db['establishments']

# %%
# review a document in the establishments collection
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65c944d0f5d232a221442878'),
#  'geocode': {'latitude': 51.083812, 'longitude': 1.195625},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
new_restaurant = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(new_restaurant)
# Out:
# InsertOneResult(ObjectId('65c948456a2d65de7847c761'), acknowledged=True)

# %%
# Check that the new restaurant was inserted
establishments.find_one({'BusinessName':'Penang Flavours'})
# Out:
# {'_id': ObjectId('65c946930c6d9c7f658b9abf'),
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'PostCode': 'SE18 7DY',
#  'Phone': '',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 0.08384, 'latitude': 51.490142},
#  'RightToReply': '',
#  'Distance': 4623.972328074718,
#  'NewRatingPending': True}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
query = {'BusinessType': 'Restaurant/Cafe/Canteen'}
fields = ['BusinessTypeID', 'BusinessType']

establishments.find_one(query, fields)
# Out:
# {'_id': ObjectId('65c944d0f5d232a221442878'),
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1}

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
establishments.update_one({'BusinessName':'Penang Flavours'},\
                         {'$set': {'BusinessTypeID': '1'}})
# Out:
# UpdateResult({'n': 1, 'nModified': 0, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Confirm that the new restaurant was updated
establishments.find_one({'BusinessName':'Penang Flavours'})
# Out:
# {'_id': ObjectId('65c946930c6d9c7f658b9abf'),
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'PostCode': 'SE18 7DY',
#  'Phone': '',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 0.08384, 'latitude': 51.490142},
#  'RightToReply': '',
#  'Distance': 4623.972328074718,
#  'NewRatingPending': True}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents in establishment
establishments.count_documents({})
# Out:
# 38787

# %%
# Find how many documents have LocalAuthorityName as "Dover"
establishments.count_documents({'LocalAuthorityName': 'Dover'})
# Out:
# 0

# %%
# Delete all documents where LocalAuthorityName is "Dover"
establishments.delete_many({'LocalAuthorityName': 'Dover'})
# Out:
# DeleteResult({'n': 0, 'ok': 1.0}, acknowledged=True)

# %%
# Check if any remaining documents include Dover
establishments.count_documents({'LocalAuthorityName': 'Dover'})
# Out:
# 0

# %%
# Check that other documents remain with 'find_one'
establishments.find_one({})
# Out:
# {'_id': ObjectId('65c944d0f5d232a221442878'),
#  'FHRSID': 1043695,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6BL',
#  'Phone': '',
#  'RatingValue': '5',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2018-04-04T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 1.195625, 'latitude': 51.083812},
#  'RightToReply': '',
#  'Distance': 4591.765489457773,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/1043695'}]}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
establishments.update_many({},\
        [{'$set': {'geocode.longitude': {'$toDouble': '$geocode.longitude'}}}])
# Out:
# UpdateResult({'n': 38787, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])
# Out:
# UpdateResult({'n': 0, 'nModified': 0, 'ok': 1.0, 'updatedExisting': False}, acknowledged=True)

# %%
# Change the data type from String to Integer for RatingValue
establishments.update_many({},\
        [{'$set': {'geocode.latitude': {'$toDouble': '$geocode.latitude'}}}])
# Out:
# UpdateResult({'n': 38787, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Check that the coordinates and rating value are now numbers
query = {'geocode.longitude', 'geocode.latitude'}
results = establishments.find({},query)
for i in results:
    pprint(i)
# Out:
# {'_id': ObjectId('65c944d0f5d232a221442878'),
#  'geocode': {'latitude': 51.083812, 'longitude': 1.195625}}
# {'_id': ObjectId('65c944d0f5d232a221442879'),
#  'geocode': {'latitude': 51.086058, 'longitude': 1.196408}}
# {'_id': ObjectId('65c944d0f5d232a22144287a'),
#  'geocode': {'latitude': 51.085797, 'longitude': 1.194762}}
# {'_id': ObjectId('65c944d0f5d232a22144287d'),
#  'geocode': {'latitude': 51.08084, 'longitude': 1.188537}}
# {'_id': ObjectId('65c944d0f5d232a22144287e'),
#  'geocode': {'latitude': 51.08084, 'longitude': 1.188537}}
# {'_id': ObjectId('65c944d0f5d232a22144287f'),
#  'geocode': {'latitude': 51.08084, 'longitude': 1.188537}}
# {'_id': ObjectId('65c944d0f5d232a221442880'),
#  'geocode': {'latitude': 51.08084, 'longitude': 1.188537}}
# {'_id': ObjectId('65c944d0f5d232a221442881'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('65c944d0f5d232a221442882'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('65c944d0f5d232a221442883'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('65c944d0f5d232a221442884'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('65c944d0f5d232a221442885'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('65c944d0f5d232a221442886'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('65c944d0f5d232a221442889'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('65c944d0f5d232a22144288a'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('65c944d0f5d232a22144288b'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('65c944d0f5d232a22144288c'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('65c944d0f5d232a22144288d'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('65c944d0f5d232a22144288e'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('65c944d0f5d232a22144288f'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('65c944d0f5d232a221442890'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('65c944d0f5d232a221442891'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('65c944d0f5d232a221442892'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('65c944d0f5d232a221442893'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('65c944d0f5d232a221442894'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('65c944d0f5d232a221442896'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('65c944d0f5d232a221442897'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('65c944d0f5d232a221442898'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('65c944d0f5d232a221442899'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('65c944d0f5d232a22144289a'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('65c944d0f5d232a22144289b'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('65c944d0f5d232a22144289c'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('65c944d0f5d232a22144289d'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('65c944d0f5d232a22144289e'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('65c944d0f5d232a22144289f'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('65c944d0f5d232a2214428a0'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('65c944d0f5d232a2214428a1'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('65c944d0f5d232a2214428a3'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('65c944d0f5d232a2214428a4'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('65c944d0f5d232a2214428a6'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('65c944d0f5d232a2214428a8'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('65c944d0f5d232a2214428aa'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('65c944d0f5d232a2214428ab'),
#  'geocode': {'latitude': 51.0805695006979, 'longitude': 1.18794649942731}}
# {'_id': ObjectId('65c944d0f5d232a2214428ac'),
#  'geocode': {'latitude': 51.078449, 'longitude': 1.18516}}
# {'_id': ObjectId('65c944d0f5d232a2214428af'),
#  'geocode': {'latitude': 51.080446, 'longitude': 1.186825}}
# {'_id': ObjectId('65c944d0f5d232a2214428b0'),
#  'geocode': {'latitude': 51.079985650005, 'longitude': 1.18628335007084}}
# {'_id': ObjectId('65c944d0f5d232a2214428b1'),
#  'geocode': {'latitude': 51.080673, 'longitude': 1.187083}}
# {'_id': ObjectId('65c944d0f5d232a2214428b2'),
#  'geocode': {'latitude': 51.080284, 'longitude': 1.186485}}
# {'_id': ObjectId('65c944d0f5d232a2214428b3'),
#  'geocode': {'latitude': 51.080284, 'longitude': 1.186485}}
# {'_id': ObjectId('65c944d0f5d232a2214428b6'),
#  'geocode': {'latitude': 51.087887, 'longitude': 1.194306}}
# {'_id': ObjectId('65c944d0f5d232a2214428b7'),
#  'geocode': {'latitude': 51.080224, 'longitude': 1.186067}}
# {'_id': ObjectId('65c944d0f5d232a2214428b8'),
#  'geocode': {'latitude': 51.079613, 'longitude': 1.185368}}
# {'_id': ObjectId('65c944d0f5d232a2214428b9'),
#  'geocode': {'latitude': 51.079613, 'longitude': 1.185368}}
# {'_id': ObjectId('65c944d0f5d232a2214428ba'),
#  'geocode': {'latitude': 51.083232, 'longitude': 1.188902}}
# {'_id': ObjectId('65c944d0f5d232a2214428bc'),
#  'geocode': {'latitude': 51.080838, 'longitude': 1.186309}}
# {'_id': ObjectId('65c944d0f5d232a2214428bd'),
#  'geocode': {'latitude': 51.081546, 'longitude': 1.186715}}
# {'_id': ObjectId('65c944d0f5d232a2214428be'),
#  'geocode': {'latitude': 51.081735, 'longitude': 1.187056}}
# {'_id': ObjectId('65c944d0f5d232a2214428bf'),
#  'geocode': {'latitude': 51.07915, 'longitude': 1.184194}}
# {'_id': ObjectId('65c944d0f5d232a2214428c0'),
#  'geocode': {'latitude': 51.07915, 'longitude': 1.184194}}
# {'_id': ObjectId('65c944d0f5d232a2214428c1'),
#  'geocode': {'latitude': 51.086262, 'longitude': 1.190896}}
# {'_id': ObjectId('65c944d0f5d232a2214428c4'),
#  'geocode': {'latitude': 51.0803, 'longitude': 1.184916}}
# {'_id': ObjectId('65c944d0f5d232a2214428c5'),
#  'geocode': {'latitude': 51.0818061828613, 'longitude': 1.18601894378662}}
# {'_id': ObjectId('65c944d0f5d232a2214428c6'),
#  'geocode': {'latitude': 51.077971, 'longitude': 1.183585}}
# {'_id': ObjectId('65c944d0f5d232a2214428c8'),
#  'geocode': {'latitude': 51.0877821, 'longitude': 1.1920251}}
# {'_id': ObjectId('65c944d0f5d232a2214428c9'),
#  'geocode': {'latitude': 51.0804824829102, 'longitude': 1.18421399593353}}
# {'_id': ObjectId('65c944d0f5d232a2214428ca'),
#  'geocode': {'latitude': 51.0804824829102, 'longitude': 1.18421399593353}}
# {'_id': ObjectId('65c944d0f5d232a2214428cb'),
#  'geocode': {'latitude': 51.0804748535156, 'longitude': 1.18425798416138}}
# {'_id': ObjectId('65c944d0f5d232a2214428cc'),
#  'geocode': {'latitude': 51.0793, 'longitude': 1.182962}}
# {'_id': ObjectId('65c944d0f5d232a2214428ce'),
#  'geocode': {'latitude': 51.079301, 'longitude': 1.182962}}
# {'_id': ObjectId('65c944d0f5d232a2214428d0'),
#  'geocode': {'latitude': 51.0809478759766, 'longitude': 1.18431901931763}}
# {'_id': ObjectId('65c944d0f5d232a2214428d1'),
#  'geocode': {'latitude': 51.080956, 'longitude': 1.18429}}
# {'_id': ObjectId('65c944d0f5d232a2214428d2'),
#  'geocode': {'latitude': 51.095015, 'longitude': 1.202055}}
# {'_id': ObjectId('65c944d0f5d232a2214428d3'),
#  'geocode': {'latitude': 51.080956, 'longitude': 1.18429}}
# {'_id': ObjectId('65c944d0f5d232a2214428d4'),
#  'geocode': {'latitude': 51.080956, 'longitude': 1.18429}}
# {'_id': ObjectId('65c944d0f5d232a2214428d5'),
#  'geocode': {'latitude': 51.080956, 'longitude': 1.18429}}
# {'_id': ObjectId('65c944d0f5d232a2214428d6'),
#  'geocode': {'latitude': 51.0917365039471, 'longitude': 1.19522100055125}}
# {'_id': ObjectId('65c944d0f5d232a2214428d7'),
#  'geocode': {'latitude': 51.097794, 'longitude': 1.201433}}
# {'_id': ObjectId('65c944d0f5d232a2214428d8'),
#  'geocode': {'latitude': 51.080805, 'longitude': 1.183894}}
# {'_id': ObjectId('65c944d0f5d232a2214428d9'),
#  'geocode': {'latitude': 51.080804, 'longitude': 1.183893}}
# {'_id': ObjectId('65c944d0f5d232a2214428da'),
#  'geocode': {'latitude': 51.079905, 'longitude': 1.182875}}
# {'_id': ObjectId('65c944d0f5d232a2214428db'),
#  'geocode': {'latitude': 51.0810258, 'longitude': 1.1835476}}
# {'_id': ObjectId('65c944d0f5d232a2214428dc'),
#  'geocode': {'latitude': 51.080339, 'longitude': 1.182805}}
# {'_id': ObjectId('65c944d0f5d232a2214428dd'),
#  'geocode': {'latitude': 51.08034, 'longitude': 1.182805}}
# {'_id': ObjectId('65c944d0f5d232a2214428de'),
#  'geocode': {'latitude': 51.08034, 'longitude': 1.182805}}
# {'_id': ObjectId('65c944d0f5d232a2214428df'),
#  'geocode': {'latitude': 51.080339, 'longitude': 1.182805}}
# {'_id': ObjectId('65c944d0f5d232a2214428e0'),
#  'geocode': {'latitude': 51.08034, 'longitude': 1.182805}}
# {'_id': ObjectId('65c944d0f5d232a2214428e2'),
#  'geocode': {'latitude': 51.0802956, 'longitude': 1.1823865}}
# {'_id': ObjectId('65c944d0f5d232a2214428e3'),
#  'geocode': {'latitude': 51.08034, 'longitude': 1.182805}}
# {'_id': ObjectId('65c944d0f5d232a2214428e4'),
#  'geocode': {'latitude': 51.079532623291, 'longitude': 1.1813759803772}}
# {'_id': ObjectId('65c944d0f5d232a2214428e5'),
#  'geocode': {'latitude': 51.079889, 'longitude': 1.181832}}
# {'_id': ObjectId('65c944d0f5d232a2214428e6'),
#  'geocode': {'latitude': 51.079542, 'longitude': 1.181365}}
# {'_id': ObjectId('65c944d0f5d232a2214428e7'),
#  'geocode': {'latitude': 51.079542, 'longitude': 1.181365}}
# {'_id': ObjectId('65c944d0f5d232a2214428e8'),
#  'geocode': {'latitude': 51.079542, 'longitude': 1.181365}}
# {'_id': ObjectId('65c944d0f5d232a2214428e9'),
#  'geocode': {'latitude': 51.080412, 'longitude': 1.182125}}
# {'_id': ObjectId('65c944d0f5d232a2214428ea'),
#  'geocode': {'latitude': 51.0798931, 'longitude': 1.1817077}}
# {'_id': ObjectId('65c944d0f5d232a2214428eb'),
#  'geocode': {'latitude': 51.0803409, 'longitude': 1.1822069}}
# {'_id': ObjectId('65c944d0f5d232a2214428ec'),
#  'geocode': {'latitude': 51.080412, 'longitude': 1.182125}}
# {'_id': ObjectId('65c944d0f5d232a2214428ed'),
#  'geocode': {'latitude': 51.078209, 'longitude': 1.179446}}
# {'_id': ObjectId('65c944d0f5d232a2214428ee'),
#  'geocode': {'latitude': 51.0802346, 'longitude': 1.1814856}}
# {'_id': ObjectId('65c944d0f5d232a2214428ef'),
#  'geocode': {'latitude': 51.079799, 'longitude': 1.181482}}
# {'_id': ObjectId('65c944d0f5d232a2214428f0'),
#  'geocode': {'latitude': 51.0797886, 'longitude': 1.1810166}}
# {'_id': ObjectId('65c944d0f5d232a2214428f1'),
#  'geocode': {'latitude': 51.0800235, 'longitude': 1.1813097}}
# {'_id': ObjectId('65c944d0f5d232a2214428f2'),
#  'geocode': {'latitude': 51.0798, 'longitude': 1.181483}}
# {'_id': ObjectId('65c944d0f5d232a2214428f3'),
#  'geocode': {'latitude': 51.0806732177734, 'longitude': 1.18172800540924}}
# {'_id': ObjectId('65c944d0f5d232a2214428f4'),
#  'geocode': {'latitude': 51.080675, 'longitude': 1.181728}}
# {'_id': ObjectId('65c944d0f5d232a2214428f5'),
#  'geocode': {'latitude': 51.080675, 'longitude': 1.181728}}
# {'_id': ObjectId('65c944d0f5d232a2214428f6'),
#  'geocode': {'latitude': 51.089491, 'longitude': 1.190904}}
# {'_id': ObjectId('65c944d0f5d232a2214428f7'),
#  'geocode': {'latitude': 51.089491, 'longitude': 1.190904}}
# {'_id': ObjectId('65c944d0f5d232a2214428f8'),
#  'geocode': {'latitude': 51.080675, 'longitude': 1.181728}}
# {'_id': ObjectId('65c944d0f5d232a2214428f9'),
#  'geocode': {'latitude': 51.0806941, 'longitude': 1.1817227}}
# {'_id': ObjectId('65c944d0f5d232a2214428fa'),
#  'geocode': {'latitude': 51.080675, 'longitude': 1.181728}}
# {'_id': ObjectId('65c944d0f5d232a2214428fb'),
#  'geocode': {'latitude': 51.0793698, 'longitude': 1.1802781}}
# {'_id': ObjectId('65c944d0f5d232a2214428fc'),
#  'geocode': {'latitude': 51.07954, 'longitude': 1.180437}}
# {'_id': ObjectId('65c944d0f5d232a2214428fd'),
#  'geocode': {'latitude': 51.080675, 'longitude': 1.181728}}
# {'_id': ObjectId('65c944d0f5d232a2214428fe'),
#  'geocode': {'latitude': 51.07954, 'longitude': 1.180437}}
# {'_id': ObjectId('65c944d0f5d232a2214428ff'),
#  'geocode': {'latitude': 51.082322, 'longitude': 1.183327}}
# {'_id': ObjectId('65c944d0f5d232a221442900'),
#  'geocode': {'latitude': 51.08164, 'longitude': 1.182609}}
# {'_id': ObjectId('65c944d0f5d232a221442901'),
#  'geocode': {'latitude': 51.07954, 'longitude': 1.180437}}
# {'_id': ObjectId('65c944d0f5d232a221442902'),
#  'geocode': {'latitude': 51.083976, 'longitude': 1.185011}}
# {'_id': ObjectId('65c944d0f5d232a221442903'),
#  'geocode': {'latitude': 51.08472, 'longitude': 1.185748}}
# {'_id': ObjectId('65c944d0f5d232a221442904'),
#  'geocode': {'latitude': 51.08164, 'longitude': 1.182609}}
# {'_id': ObjectId('65c944d0f5d232a221442905'),
#  'geocode': {'latitude': 51.07954, 'longitude': 1.180437}}
# {'_id': ObjectId('65c944d0f5d232a221442906'),
#  'geocode': {'latitude': 51.0818634033203, 'longitude': 1.18279695510864}}
# {'_id': ObjectId('65c944d0f5d232a221442907'),
#  'geocode': {'latitude': 51.0816612, 'longitude': 1.1826116}}
# {'_id': ObjectId('65c944d0f5d232a221442908'),
#  'geocode': {'latitude': 51.084721, 'longitude': 1.185748}}
# {'_id': ObjectId('65c944d0f5d232a221442909'),
#  'geocode': {'latitude': 51.0804176330566, 'longitude': 1.18128204345703}}
# {'_id': ObjectId('65c944d0f5d232a22144290a'),
#  'geocode': {'latitude': 51.080181, 'longitude': 1.181023}}
# {'_id': ObjectId('65c944d0f5d232a22144290b'),
#  'geocode': {'latitude': 51.080675, 'longitude': 1.181728}}
# {'_id': ObjectId('65c944d0f5d232a22144290c'),
#  'geocode': {'latitude': 51.080417, 'longitude': 1.181282}}
# {'_id': ObjectId('65c944d0f5d232a22144290d'),
#  'geocode': {'latitude': 51.08187, 'longitude': 1.182753}}
# {'_id': ObjectId('65c944d0f5d232a22144290e'),
#  'geocode': {'latitude': 51.081494, 'longitude': 1.182356}}
# {'_id': ObjectId('65c944d0f5d232a22144290f'),
#  'geocode': {'latitude': 51.08187, 'longitude': 1.182753}}
# {'_id': ObjectId('65c944d0f5d232a221442910'),
#  'geocode': {'latitude': 51.08187, 'longitude': 1.182753}}
# {'_id': ObjectId('65c944d0f5d232a221442911'),
#  'geocode': {'latitude': 51.078296, 'longitude': 1.178909}}
# {'_id': ObjectId('65c944d0f5d232a221442912'),
#  'geocode': {'latitude': 51.078296, 'longitude': 1.178909}}
# {'_id': ObjectId('65c944d0f5d232a221442913'),
#  'geocode': {'latitude': 51.085454, 'longitude': 1.186241}}
# {'_id': ObjectId('65c944d0f5d232a221442914'),
#  'geocode': {'latitude': 51.080417, 'longitude': 1.181282}}
# {'_id': ObjectId('65c944d0f5d232a221442915'),
#  'geocode': {'latitude': 51.086189, 'longitude': 1.186977}}
# {'_id': ObjectId('65c944d0f5d232a221442916'),
#  'geocode': {'latitude': 51.078296, 'longitude': 1.178909}}
# {'_id': ObjectId('65c944d0f5d232a221442917'),
#  'geocode': {'latitude': 51.086189, 'longitude': 1.186977}}
# {'_id': ObjectId('65c944d0f5d232a221442918'),
#  'geocode': {'latitude': 51.078296, 'longitude': 1.178909}}
# {'_id': ObjectId('65c944d0f5d232a221442919'),
#  'geocode': {'latitude': 51.0785865783691, 'longitude': 1.17911505699158}}
# {'_id': ObjectId('65c944d0f5d232a22144291a'),
#  'geocode': {'latitude': 51.078587, 'longitude': 1.179115}}
# {'_id': ObjectId('65c944d0f5d232a22144291c'),
#  'geocode': {'latitude': 51.0780695, 'longitude': 1.1785097}}
# {'_id': ObjectId('65c944d0f5d232a22144291d'),
#  'geocode': {'latitude': 51.0781968, 'longitude': 1.1783613}}
# {'_id': ObjectId('65c944d0f5d232a22144291e'),
#  'geocode': {'latitude': 51.0802287, 'longitude': 1.1806797}}
# {'_id': ObjectId('65c944d0f5d232a221442920'),
#  'geocode': {'latitude': 51.0798709, 'longitude': 1.1803396}}
# {'_id': ObjectId('65c944d0f5d232a221442921'),
#  'geocode': {'latitude': 51.078117, 'longitude': 1.1784815}}
# {'_id': ObjectId('65c944d0f5d232a221442922'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('65c944d0f5d232a221442923'),
#  'geocode': {'latitude': 51.083569, 'longitude': 1.183784}}
# {'_id': ObjectId('65c944d0f5d232a221442924'),
#  'geocode': {'latitude': 51.080315, 'longitude': 1.18039}}
# {'_id': ObjectId('65c944d0f5d232a221442925'),
#  'geocode': {'latitude': 51.079632, 'longitude': 1.179729}}
# {'_id': ObjectId('65c944d0f5d232a221442927'),
#  'geocode': {'latitude': 51.079632, 'longitude': 1.179729}}
# {'_id': ObjectId('65c944d0f5d232a221442928'),
#  'geocode': {'latitude': 51.083569, 'longitude': 1.183784}}
# {'_id': ObjectId('65c944d0f5d232a221442929'),
#  'geocode': {'latitude': 51.081526, 'longitude': 1.181201}}
# {'_id': ObjectId('65c944d0f5d232a22144292a'),
#  'geocode': {'latitude': 51.080315, 'longitude': 1.18039}}
# {'_id': ObjectId('65c944d0f5d232a22144292b'),
#  'geocode': {'latitude': 51.0818613, 'longitude': 1.1818685}}
# {'_id': ObjectId('65c944d0f5d232a22144292d'),
#  'geocode': {'latitude': 51.079482, 'longitude': 1.178962}}
# {'_id': ObjectId('65c944d0f5d232a22144292e'),
#  'geocode': {'latitude': 51.081337, 'longitude': 1.180846}}
# {'_id': ObjectId('65c944d0f5d232a22144292f'),
#  'geocode': {'latitude': 51.081337, 'longitude': 1.180846}}
# {'_id': ObjectId('65c944d0f5d232a221442931'),
#  'geocode': {'latitude': 51.0783483, 'longitude': 1.177752}}
# {'_id': ObjectId('65c944d0f5d232a221442932'),
#  'geocode': {'latitude': 51.0783433, 'longitude': 1.1776046}}
# {'_id': ObjectId('65c944d0f5d232a221442933'),
#  'geocode': {'latitude': 51.088735, 'longitude': 1.188295}}
# {'_id': ObjectId('65c944d0f5d232a221442934'),
#  'geocode': {'latitude': 51.088735, 'longitude': 1.188295}}
# {'_id': ObjectId('65c944d0f5d232a221442935'),
#  'geocode': {'latitude': 51.0824157, 'longitude': 1.1817418}}
# {'_id': ObjectId('65c944d0f5d232a221442936'),
#  'geocode': {'latitude': 51.078317, 'longitude': 1.177468}}
# {'_id': ObjectId('65c944d0f5d232a221442937'),
#  'geocode': {'latitude': 51.078317, 'longitude': 1.177468}}
# {'_id': ObjectId('65c944d0f5d232a221442938'),
#  'geocode': {'latitude': 51.078317, 'longitude': 1.177468}}
# {'_id': ObjectId('65c944d0f5d232a221442939'),
#  'geocode': {'latitude': 51.078317, 'longitude': 1.177468}}
# {'_id': ObjectId('65c944d0f5d232a22144293a'),
#  'geocode': {'latitude': 51.082867, 'longitude': 1.182136}}
# {'_id': ObjectId('65c944d0f5d232a22144293b'),
#  'geocode': {'latitude': 51.078131, 'longitude': 1.178027}}
# {'_id': ObjectId('65c944d0f5d232a22144293c'),
#  'geocode': {'latitude': 51.0818613, 'longitude': 1.1818685}}
# {'_id': ObjectId('65c944d0f5d232a22144293d'),
#  'geocode': {'latitude': 51.0781968, 'longitude': 1.1783613}}
# {'_id': ObjectId('65c944d0f5d232a22144293f'),
#  'geocode': {'latitude': 51.082867, 'longitude': 1.182136}}
# {'_id': ObjectId('65c944d0f5d232a221442941'),
#  'geocode': {'latitude': 51.087132, 'longitude': 1.186371}}
# {'_id': ObjectId('65c944d0f5d232a221442942'),
#  'geocode': {'latitude': 51.0806446, 'longitude': 1.1796215}}
# {'_id': ObjectId('65c944d0f5d232a221442943'),
#  'geocode': {'latitude': 51.080668, 'longitude': 1.179628}}
# {'_id': ObjectId('65c944d0f5d232a221442944'),
#  'geocode': {'latitude': 51.080669, 'longitude': 1.179629}}
# {'_id': ObjectId('65c944d0f5d232a221442945'),
#  'geocode': {'latitude': 51.080669, 'longitude': 1.179629}}
# {'_id': ObjectId('65c944d0f5d232a221442946'),
#  'geocode': {'latitude': 51.0804496, 'longitude': 1.1794011}}
# {'_id': ObjectId('65c944d0f5d232a221442947'),
#  'geocode': {'latitude': 51.083108, 'longitude': 1.181896}}
# {'_id': ObjectId('65c944d0f5d232a221442948'),
#  'geocode': {'latitude': 51.076896, 'longitude': 1.175486}}
# {'_id': ObjectId('65c944d0f5d232a221442949'),
#  'geocode': {'latitude': 51.078211, 'longitude': 1.176733}}
# {'_id': ObjectId('65c944d0f5d232a22144294a'),
#  'geocode': {'latitude': 51.0782127380371, 'longitude': 1.17673301696777}}
# {'_id': ObjectId('65c944d0f5d232a22144294b'),
#  'geocode': {'latitude': 51.0808513, 'longitude': 1.1794486}}
# {'_id': ObjectId('65c944d0f5d232a22144294c'),
#  'geocode': {'latitude': 51.079081, 'longitude': 1.177506}}
# {'_id': ObjectId('65c944d0f5d232a22144294d'),
#  'geocode': {'latitude': 51.0810699462891, 'longitude': 1.17957198619843}}
# {'_id': ObjectId('65c944d0f5d232a22144294e'),
#  'geocode': {'latitude': 51.079482, 'longitude': 1.178962}}
# {'_id': ObjectId('65c944d0f5d232a22144294f'),
#  'geocode': {'latitude': 51.079081, 'longitude': 1.177506}}
# {'_id': ObjectId('65c944d0f5d232a221442950'),
#  'geocode': {'latitude': 51.079679, 'longitude': 1.17799}}
# {'_id': ObjectId('65c944d0f5d232a221442951'),
#  'geocode': {'latitude': 51.080624, 'longitude': 1.178969}}
# {'_id': ObjectId('65c944d0f5d232a221442952'),
#  'geocode': {'latitude': 51.079679, 'longitude': 1.17799}}
# {'_id': ObjectId('65c944d0f5d232a221442953'),
#  'geocode': {'latitude': 51.079679, 'longitude': 1.17799}}
# {'_id': ObjectId('65c944d0f5d232a221442954'),
#  'geocode': {'latitude': 51.079679, 'longitude': 1.17799}}
# {'_id': ObjectId('65c944d0f5d232a221442955'),
#  'geocode': {'latitude': 51.076653, 'longitude': 1.174813}}
# {'_id': ObjectId('65c944d0f5d232a221442956'),
#  'geocode': {'latitude': 51.0776252746582, 'longitude': 1.17575001716614}}
# {'_id': ObjectId('65c944d0f5d232a221442957'),
#  'geocode': {'latitude': 51.077626, 'longitude': 1.17575}}
# {'_id': ObjectId('65c944d0f5d232a221442958'),
#  'geocode': {'latitude': 51.077626, 'longitude': 1.17575}}
# {'_id': ObjectId('65c944d0f5d232a221442959'),
#  'geocode': {'latitude': 51.077626, 'longitude': 1.17575}}
# {'_id': ObjectId('65c944d0f5d232a22144295a'),
#  'geocode': {'latitude': 51.077626, 'longitude': 1.17575}}
# {'_id': ObjectId('65c944d0f5d232a22144295b'),
#  'geocode': {'latitude': 51.077626, 'longitude': 1.17575}}
# {'_id': ObjectId('65c944d0f5d232a22144295c'),
#  'geocode': {'latitude': 51.087185, 'longitude': 1.185418}}
# {'_id': ObjectId('65c944d0f5d232a22144295d'),
#  'geocode': {'latitude': 51.0758056640625, 'longitude': 1.17352676391602}}
# {'_id': ObjectId('65c944d0f5d232a22144295e'),
#  'geocode': {'latitude': 51.076956, 'longitude': 1.174605}}
# {'_id': ObjectId('65c944d0f5d232a22144295f'),
#  'geocode': {'latitude': 51.0776458, 'longitude': 1.1753663}}
# {'_id': ObjectId('65c944d0f5d232a221442960'),
#  'geocode': {'latitude': 51.080211, 'longitude': 1.179925}}
# {'_id': ObjectId('65c944d0f5d232a221442961'),
#  'geocode': {'latitude': 51.080211, 'longitude': 1.179926}}
# {'_id': ObjectId('65c944d0f5d232a221442962'),
#  'geocode': {'latitude': 51.080211, 'longitude': 1.179926}}
# {'_id': ObjectId('65c944d0f5d232a221442963'),
#  'geocode': {'latitude': 51.080217, 'longitude': 1.1799178}}
# {'_id': ObjectId('65c944d0f5d232a221442964'),
#  'geocode': {'latitude': 51.076956, 'longitude': 1.174605}}
# {'_id': ObjectId('65c944d0f5d232a221442965'),
#  'geocode': {'latitude': 51.078718, 'longitude': 1.176296}}
# {'_id': ObjectId('65c944d0f5d232a221442966'),
#  'geocode': {'latitude': 51.079161, 'longitude': 1.17884}}
# {'_id': ObjectId('65c944d0f5d232a221442967'),
#  'geocode': {'latitude': 51.079481, 'longitude': 1.178961}}
# {'_id': ObjectId('65c944d0f5d232a221442968'),
#  'geocode': {'latitude': 51.078718, 'longitude': 1.176296}}
# {'_id': ObjectId('65c944d0f5d232a221442969'),
#  'geocode': {'latitude': 51.078033, 'longitude': 1.17535}}
# {'_id': ObjectId('65c944d0f5d232a22144296a'),
#  'geocode': {'latitude': 51.078033, 'longitude': 1.17535}}
# {'_id': ObjectId('65c944d0f5d232a22144296b'),
#  'geocode': {'latitude': 51.078513, 'longitude': 1.175897}}
# {'_id': ObjectId('65c944d0f5d232a22144296c'),
#  'geocode': {'latitude': 51.07879, 'longitude': 1.176258}}
# {'_id': ObjectId('65c944d0f5d232a22144296d'),
#  'geocode': {'latitude': 51.0788531, 'longitude': 1.1762215}}
# {'_id': ObjectId('65c944d0f5d232a22144296e'),
#  'geocode': {'latitude': 51.09221, 'longitude': 1.189834}}
# {'_id': ObjectId('65c944d0f5d232a22144296f'),
#  'geocode': {'latitude': 51.078033, 'longitude': 1.17535}}
# {'_id': ObjectId('65c944d0f5d232a221442970'),
#  'geocode': {'latitude': 51.087382, 'longitude': 1.184803}}
# {'_id': ObjectId('65c944d0f5d232a221442971'),
#  'geocode': {'latitude': 51.09221, 'longitude': 1.189833}}
# {'_id': ObjectId('65c944d0f5d232a221442972'),
#  'geocode': {'latitude': 51.07873, 'longitude': 1.17584}}
# {'_id': ObjectId('65c944d0f5d232a221442973'),
#  'geocode': {'latitude': 51.07873, 'longitude': 1.17584}}
# {'_id': ObjectId('65c944d0f5d232a221442974'),
#  'geocode': {'latitude': 51.0787391662598, 'longitude': 1.17591404914856}}
# {'_id': ObjectId('65c944d0f5d232a221442975'),
#  'geocode': {'latitude': 51.078033, 'longitude': 1.17535}}
# {'_id': ObjectId('65c944d0f5d232a221442976'),
#  'geocode': {'latitude': 51.078515, 'longitude': 1.175811}}
# {'_id': ObjectId('65c944d0f5d232a221442977'),
#  'geocode': {'latitude': 51.07873, 'longitude': 1.17584}}
# {'_id': ObjectId('65c944d0f5d232a221442978'),
#  'geocode': {'latitude': 51.088115, 'longitude': 1.18431}}
# {'_id': ObjectId('65c944d0f5d232a221442979'),
#  'geocode': {'latitude': 51.088115, 'longitude': 1.18431}}
# {'_id': ObjectId('65c944d0f5d232a22144297a'),
#  'geocode': {'latitude': 51.088115, 'longitude': 1.18431}}
# {'_id': ObjectId('65c944d0f5d232a22144297b'),
#  'geocode': {'latitude': 51.088115, 'longitude': 1.18431}}
# {'_id': ObjectId('65c944d0f5d232a22144297c'),
#  'geocode': {'latitude': 51.0881644, 'longitude': 1.1842719}}
# {'_id': ObjectId('65c944d0f5d232a22144297d'),
#  'geocode': {'latitude': 51.076413, 'longitude': 1.172055}}
# {'_id': ObjectId('65c944d0f5d232a22144297e'),
#  'geocode': {'latitude': 51.079039, 'longitude': 1.174748}}
# {'_id': ObjectId('65c944d0f5d232a22144297f'),
#  'geocode': {'latitude': 51.077492, 'longitude': 1.173056}}
# {'_id': ObjectId('65c944d0f5d232a221442980'),
#  'geocode': {'latitude': 51.080171, 'longitude': 1.175782}}
# {'_id': ObjectId('65c944d0f5d232a221442981'),
#  'geocode': {'latitude': 51.080171, 'longitude': 1.175782}}
# {'_id': ObjectId('65c944d0f5d232a221442982'),
#  'geocode': {'latitude': 51.076577, 'longitude': 1.17198}}
# {'_id': ObjectId('65c944d0f5d232a221442983'),
#  'geocode': {'latitude': 51.076577, 'longitude': 1.17198}}
# {'_id': ObjectId('65c944d0f5d232a221442984'),
#  'geocode': {'latitude': 51.077414, 'longitude': 1.172652}}
# {'_id': ObjectId('65c944d0f5d232a221442985'),
#  'geocode': {'latitude': 51.088333, 'longitude': 1.183925}}
# {'_id': ObjectId('65c944d0f5d232a221442986'),
#  'geocode': {'latitude': 51.077414, 'longitude': 1.172652}}
# {'_id': ObjectId('65c944d0f5d232a221442987'),
#  'geocode': {'latitude': 51.089337, 'longitude': 1.18468}}
# {'_id': ObjectId('65c944d0f5d232a221442988'),
#  'geocode': {'latitude': 51.078033, 'longitude': 1.17535}}
# {'_id': ObjectId('65c944d0f5d232a221442989'),
#  'geocode': {'latitude': 51.090286, 'longitude': 1.185859}}
# {'_id': ObjectId('65c944d0f5d232a22144298a'),
#  'geocode': {'latitude': 51.078515, 'longitude': 1.175811}}
# {'_id': ObjectId('65c944d0f5d232a22144298b'),
#  'geocode': {'latitude': 51.07856, 'longitude': 1.1748}}
# {'_id': ObjectId('65c944d0f5d232a22144298c'),
#  'geocode': {'latitude': 51.076647, 'longitude': 1.172728}}
# {'_id': ObjectId('65c944d0f5d232a22144298d'),
#  'geocode': {'latitude': 51.0812644958496, 'longitude': 1.17841398715973}}
# {'_id': ObjectId('65c944d0f5d232a22144298e'),
#  'geocode': {'latitude': 51.0806630002457, 'longitude': 1.17725700019713}}
# {'_id': ObjectId('65c944d0f5d232a22144298f'),
#  'geocode': {'latitude': 51.07873, 'longitude': 1.17584}}
# {'_id': ObjectId('65c944d0f5d232a221442990'),
#  'geocode': {'latitude': 51.076647, 'longitude': 1.172728}}
# {'_id': ObjectId('65c944d0f5d232a221442991'),
#  'geocode': {'latitude': 51.0833323, 'longitude': 1.1784191}}
# {'_id': ObjectId('65c944d0f5d232a221442992'),
#  'geocode': {'latitude': 51.091129, 'longitude': 1.186289}}
# {'_id': ObjectId('65c944d0f5d232a221442993'),
#  'geocode': {'latitude': 51.076647, 'longitude': 1.172728}}
# {'_id': ObjectId('65c944d0f5d232a221442994'),
#  'geocode': {'latitude': 51.088115, 'longitude': 1.18431}}
# {'_id': ObjectId('65c944d0f5d232a221442995'),
#  'geocode': {'latitude': 51.074167, 'longitude': 1.16866}}
# {'_id': ObjectId('65c944d0f5d232a221442996'),
#  'geocode': {'latitude': 51.077702, 'longitude': 1.172314}}
# {'_id': ObjectId('65c944d0f5d232a221442998'),
#  'geocode': {'latitude': 51.078197, 'longitude': 1.172619}}
# {'_id': ObjectId('65c944d0f5d232a221442999'),
#  'geocode': {'latitude': 51.078197, 'longitude': 1.172619}}
# {'_id': ObjectId('65c944d0f5d232a22144299a'),
#  'geocode': {'latitude': 51.078197, 'longitude': 1.172619}}
# {'_id': ObjectId('65c944d0f5d232a22144299b'),
#  'geocode': {'latitude': 51.078197, 'longitude': 1.172619}}
# {'_id': ObjectId('65c944d0f5d232a22144299c'),
#  'geocode': {'latitude': 51.078197, 'longitude': 1.172619}}
# {'_id': ObjectId('65c944d0f5d232a22144299d'),
#  'geocode': {'latitude': 51.078197, 'longitude': 1.172619}}
# {'_id': ObjectId('65c944d0f5d232a22144299e'),
#  'geocode': {'latitude': 51.088115, 'longitude': 1.18431}}
# {'_id': ObjectId('65c944d0f5d232a22144299f'),
#  'geocode': {'latitude': 51.078197, 'longitude': 1.172619}}
# {'_id': ObjectId('65c944d0f5d232a2214429a0'),
#  'geocode': {'latitude': 51.078197, 'longitude': 1.172619}}
# {'_id': ObjectId('65c944d0f5d232a2214429a1'),
#  'geocode': {'latitude': 51.082871, 'longitude': 1.177367}}
# {'_id': ObjectId('65c944d0f5d232a2214429a2'),
#  'geocode': {'latitude': 51.079192, 'longitude': 1.173416}}
# {'_id': ObjectId('65c944d0f5d232a2214429a3'),
#  'geocode': {'latitude': 51.078068, 'longitude': 1.172054}}
# {'_id': ObjectId('65c944d0f5d232a2214429a4'),
#  'geocode': {'latitude': 51.082381, 'longitude': 1.176219}}
# {'_id': ObjectId('65c944d0f5d232a2214429a5'),
#  'geocode': {'latitude': 51.078885, 'longitude': 1.172452}}
# {'_id': ObjectId('65c944d0f5d232a2214429a6'),
#  'geocode': {'latitude': 51.081154, 'longitude': 1.174678}}
# {'_id': ObjectId('65c944d0f5d232a2214429a7'),
#  'geocode': {'latitude': 51.07623, 'longitude': 1.169515}}
# {'_id': ObjectId('65c944d0f5d232a2214429a8'),
#  'geocode': {'latitude': 51.07623, 'longitude': 1.169515}}
# {'_id': ObjectId('65c944d0f5d232a2214429a9'),
#  'geocode': {'latitude': 51.075403, 'longitude': 1.168516}}
# {'_id': ObjectId('65c944d0f5d232a2214429aa'),
#  'geocode': {'latitude': 51.085038, 'longitude': 1.177729}}
# {'_id': ObjectId('65c944d0f5d232a2214429ab'),
#  'geocode': {'latitude': 51.078874, 'longitude': 1.171552}}
# {'_id': ObjectId('65c944d0f5d232a2214429ac'),
#  'geocode': {'latitude': 51.085001, 'longitude': 1.177755}}
# {'_id': ObjectId('65c944d0f5d232a2214429ad'),
#  'geocode': {'latitude': 51.085038, 'longitude': 1.177729}}
# {'_id': ObjectId('65c944d0f5d232a2214429ae'),
#  'geocode': {'latitude': 51.085038, 'longitude': 1.177729}}
# {'_id': ObjectId('65c944d0f5d232a2214429af'),
#  'geocode': {'latitude': 51.088893, 'longitude': 1.181507}}
# {'_id': ObjectId('65c944d0f5d232a2214429b0'),
#  'geocode': {'latitude': 51.08129, 'longitude': 1.17363}}
# {'_id': ObjectId('65c944d0f5d232a2214429b1'),
#  'geocode': {'latitude': 51.081291, 'longitude': 1.173631}}
# {'_id': ObjectId('65c944d0f5d232a2214429b2'),
#  'geocode': {'latitude': 51.081291, 'longitude': 1.173631}}
# {'_id': ObjectId('65c944d0f5d232a2214429b3'),
#  'geocode': {'latitude': 51.077243, 'longitude': 1.168984}}
# {'_id': ObjectId('65c944d0f5d232a2214429b4'),
#  'geocode': {'latitude': 51.088124, 'longitude': 1.179997}}
# {'_id': ObjectId('65c944d0f5d232a2214429b5'),
#  'geocode': {'latitude': 51.0819, 'longitude': 1.17373}}
# {'_id': ObjectId('65c944d0f5d232a2214429b6'),
#  'geocode': {'latitude': 51.086485, 'longitude': 1.178428}}
# {'_id': ObjectId('65c944d0f5d232a2214429b7'),
#  'geocode': {'latitude': 51.088125, 'longitude': 1.179998}}
# {'_id': ObjectId('65c944d0f5d232a2214429b8'),
#  'geocode': {'latitude': 51.087034, 'longitude': 1.178766}}
# {'_id': ObjectId('65c944d0f5d232a2214429b9'),
#  'geocode': {'latitude': 51.087034, 'longitude': 1.178766}}
# {'_id': ObjectId('65c944d0f5d232a2214429ba'),
#  'geocode': {'latitude': 51.087034, 'longitude': 1.178766}}
# {'_id': ObjectId('65c944d0f5d232a2214429bb'),
#  'geocode': {'latitude': 51.080533, 'longitude': 1.172065}}
# {'_id': ObjectId('65c944d0f5d232a2214429bc'),
#  'geocode': {'latitude': 51.085872, 'longitude': 1.177515}}
# {'_id': ObjectId('65c944d0f5d232a2214429be'),
#  'geocode': {'latitude': 51.080302, 'longitude': 1.171635}}
# {'_id': ObjectId('65c944d0f5d232a2214429c0'),
#  'geocode': {'latitude': 51.077289, 'longitude': 1.168302}}
# {'_id': ObjectId('65c944d0f5d232a2214429c1'),
#  'geocode': {'latitude': 51.085365, 'longitude': 1.176952}}
# {'_id': ObjectId('65c944d0f5d232a2214429c2'),
#  'geocode': {'latitude': 51.088806, 'longitude': 1.180073}}
# {'_id': ObjectId('65c944d0f5d232a2214429c3'),
#  'geocode': {'latitude': 51.082332, 'longitude': 1.17306}}
# {'_id': ObjectId('65c944d0f5d232a2214429c4'),
#  'geocode': {'latitude': 51.090168, 'longitude': 1.181609}}
# {'_id': ObjectId('65c944d0f5d232a2214429c5'),
#  'geocode': {'latitude': 51.090195, 'longitude': 1.18094}}
# {'_id': ObjectId('65c944d0f5d232a2214429c6'),
#  'geocode': {'latitude': 51.082331, 'longitude': 1.173059}}
# {'_id': ObjectId('65c944d0f5d232a2214429c7'),
#  'geocode': {'latitude': 51.08885, 'longitude': 1.180133}}
# {'_id': ObjectId('65c944d0f5d232a2214429c8'),
#  'geocode': {'latitude': 51.08186, 'longitude': 1.171556}}
# {'_id': ObjectId('65c944d0f5d232a2214429c9'),
#  'geocode': {'latitude': 51.085553, 'longitude': 1.175337}}
# {'_id': ObjectId('65c944d0f5d232a2214429ca'),
#  'geocode': {'latitude': 51.081795, 'longitude': 1.172295}}
# {'_id': ObjectId('65c944d0f5d232a2214429cb'),
#  'geocode': {'latitude': 51.082374, 'longitude': 1.171506}}
# {'_id': ObjectId('65c944d0f5d232a2214429cc'),
#  'geocode': {'latitude': 51.0817527770996, 'longitude': 1.17090594768524}}
# {'_id': ObjectId('65c944d0f5d232a2214429cd'),
#  'geocode': {'latitude': 51.085552, 'longitude': 1.175336}}
# {'_id': ObjectId('65c944d0f5d232a2214429ce'),
#  'geocode': {'latitude': 51.07555, 'longitude': 1.165413}}
# {'_id': ObjectId('65c944d0f5d232a2214429cf'),
#  'geocode': {'latitude': 51.0769439, 'longitude': 1.1665238}}
# {'_id': ObjectId('65c944d0f5d232a2214429d0'),
#  'geocode': {'latitude': 51.077737, 'longitude': 1.167704}}
# {'_id': ObjectId('65c944d0f5d232a2214429d1'),
#  'geocode': {'latitude': 51.0932246, 'longitude': 1.1829433}}
# {'_id': ObjectId('65c944d0f5d232a2214429d2'),
#  'geocode': {'latitude': 51.0751419067383, 'longitude': 1.16350066661835}}
# {'_id': ObjectId('65c944d0f5d232a2214429d3'),
#  'geocode': {'latitude': 51.08382, 'longitude': 1.171591}}
# {'_id': ObjectId('65c944d0f5d232a2214429d4'),
#  'geocode': {'latitude': 51.095177, 'longitude': 1.182639}}
# {'_id': ObjectId('65c944d0f5d232a2214429d5'),
#  'geocode': {'latitude': 51.078911, 'longitude': 1.165543}}
# {'_id': ObjectId('65c944d0f5d232a2214429d6'),
#  'geocode': {'latitude': 51.076949, 'longitude': 1.164581}}
# {'_id': ObjectId('65c944d0f5d232a2214429d7'),
#  'geocode': {'latitude': 51.082374, 'longitude': 1.171506}}
# {'_id': ObjectId('65c944d0f5d232a2214429d8'),
#  'geocode': {'latitude': 51.083812713623, 'longitude': 1.17163395881653}}
# {'_id': ObjectId('65c944d0f5d232a2214429db'),
#  'geocode': {'latitude': 51.085755, 'longitude': 1.172865}}
# {'_id': ObjectId('65c944d0f5d232a2214429de'),
#  'geocode': {'latitude': 51.080017, 'longitude': 1.164533}}
# {'_id': ObjectId('65c944d0f5d232a2214429df'),
#  'geocode': {'latitude': 51.087373, 'longitude': 1.171919}}
# {'_id': ObjectId('65c944d0f5d232a2214429e0'),
#  'geocode': {'latitude': 51.087373, 'longitude': 1.171919}}
# {'_id': ObjectId('65c944d0f5d232a2214429e1'),
#  'geocode': {'latitude': 51.079404, 'longitude': 1.16362}}
# {'_id': ObjectId('65c944d0f5d232a2214429e3'),
#  'geocode': {'latitude': 51.076559, 'longitude': 1.160028}}
# {'_id': ObjectId('65c944d0f5d232a2214429e5'),
#  'geocode': {'latitude': 51.082434, 'longitude': 1.165969}}
# {'_id': ObjectId('65c944d0f5d232a2214429e7'),
#  'geocode': {'latitude': 51.082374, 'longitude': 1.171506}}
# {'_id': ObjectId('65c944d0f5d232a2214429e8'),
#  'geocode': {'latitude': 51.07507, 'longitude': 1.162196}}
# {'_id': ObjectId('65c944d0f5d232a2214429e9'),
#  'geocode': {'latitude': 51.095177, 'longitude': 1.182639}}
# {'_id': ObjectId('65c944d0f5d232a2214429ea'),
#  'geocode': {'latitude': 51.095177, 'longitude': 1.182639}}
# {'_id': ObjectId('65c944d0f5d232a2214429eb'),
#  'geocode': {'latitude': 51.095177, 'longitude': 1.182639}}
# {'_id': ObjectId('65c944d0f5d232a2214429ef'),
#  'geocode': {'latitude': 51.085565, 'longitude': 1.168597}}
# {'_id': ObjectId('65c944d0f5d232a2214429f0'),
#  'geocode': {'latitude': 51.0813407897949, 'longitude': 1.16422498226166}}
# {'_id': ObjectId('65c944d0f5d232a2214429f1'),
#  'geocode': {'latitude': 51.081358, 'longitude': 1.164182}}
# {'_id': ObjectId('65c944d0f5d232a2214429f3'),
#  'geocode': {'latitude': 51.084325, 'longitude': 1.166898}}
# {'_id': ObjectId('65c944d0f5d232a2214429f4'),
#  'geocode': {'latitude': 51.084325, 'longitude': 1.166898}}
# {'_id': ObjectId('65c944d0f5d232a2214429f5'),
#  'geocode': {'latitude': 51.090416, 'longitude': 1.173128}}
# {'_id': ObjectId('65c944d0f5d232a2214429f6'),
#  'geocode': {'latitude': 51.090416, 'longitude': 1.173128}}
# {'_id': ObjectId('65c944d0f5d232a2214429f7'),
#  'geocode': {'latitude': 51.3344841003418, 'longitude': 1.42664802074432}}
# {'_id': ObjectId('65c944d0f5d232a2214429f8'),
#  'geocode': {'latitude': 51.335713, 'longitude': 1.427746}}
# {'_id': ObjectId('65c944d0f5d232a2214429f9'),
#  'geocode': {'latitude': 51.335713, 'longitude': 1.427746}}
# {'_id': ObjectId('65c944d0f5d232a2214429fa'),
#  'geocode': {'latitude': 51.336816, 'longitude': 1.428762}}
# {'_id': ObjectId('65c944d0f5d232a2214429fc'),
#  'geocode': {'latitude': 51.085871, 'longitude': 1.167918}}
# {'_id': ObjectId('65c944d0f5d232a2214429fd'),
#  'geocode': {'latitude': 51.076715, 'longitude': 1.158282}}
# {'_id': ObjectId('65c944d0f5d232a2214429fe'),
#  'geocode': {'latitude': 51.338414, 'longitude': 1.429786}}
# {'_id': ObjectId('65c944d0f5d232a2214429ff'),
#  'geocode': {'latitude': 51.338414, 'longitude': 1.429786}}
# {'_id': ObjectId('65c944d0f5d232a221442a01'),
#  'geocode': {'latitude': 51.3322105407715, 'longitude': 1.42320394515991}}
# {'_id': ObjectId('65c944d0f5d232a221442a02'),
#  'geocode': {'latitude': 51.33222, 'longitude': 1.423192}}
# {'_id': ObjectId('65c944d0f5d232a221442a03'),
#  'geocode': {'latitude': 51.33222, 'longitude': 1.423192}}
# {'_id': ObjectId('65c944d0f5d232a221442a04'),
#  'geocode': {'latitude': 51.33222, 'longitude': 1.423192}}
# {'_id': ObjectId('65c944d0f5d232a221442a05'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'_id': ObjectId('65c944d0f5d232a221442a06'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'_id': ObjectId('65c944d0f5d232a221442a07'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'_id': ObjectId('65c944d0f5d232a221442a08'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'_id': ObjectId('65c944d0f5d232a221442a09'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'_id': ObjectId('65c944d0f5d232a221442a0a'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'_id': ObjectId('65c944d0f5d232a221442a0b'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'_id': ObjectId('65c944d0f5d232a221442a0c'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'_id': ObjectId('65c944d0f5d232a221442a0d'),
#  'geocode': {'latitude': 51.08538, 'longitude': 1.171755}}
# {'_id': ObjectId('65c944d0f5d232a221442a0e'),
#  'geocode': {'latitude': 51.082833, 'longitude': 1.168524}}
# {'_id': ObjectId('65c944d0f5d232a221442a11'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'_id': ObjectId('65c944d0f5d232a221442a12'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'_id': ObjectId('65c944d0f5d232a221442a13'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'_id': ObjectId('65c944d0f5d232a221442a14'),
#  'geocode': {'latitude': 51.3322219848633, 'longitude': 1.42319202423096}}
# {'_id': ObjectId('65c944d0f5d232a221442a15'),
#  'geocode': {'latitude': 51.092175, 'longitude': 1.173634}}
# {'_id': ObjectId('65c944d0f5d232a221442a16'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'_id': ObjectId('65c944d0f5d232a221442a18'),
#  'geocode': {'latitude': 51.3322219848633, 'longitude': 1.42319202423096}}
# {'_id': ObjectId('65c944d0f5d232a221442a19'),
#  'geocode': {'latitude': 51.3351135253906, 'longitude': 1.42612195014954}}
# {'_id': ObjectId('65c944d0f5d232a221442a1a'),
#  'geocode': {'latitude': 51.331022, 'longitude': 1.421136}}
# {'_id': ObjectId('65c944d0f5d232a221442a1b'),
#  'geocode': {'latitude': 51.087041, 'longitude': 1.168241}}
# {'_id': ObjectId('65c944d0f5d232a221442a1c'),
#  'geocode': {'latitude': 51.332386, 'longitude': 1.421525}}
# {'_id': ObjectId('65c944d0f5d232a221442a1d'),
#  'geocode': {'latitude': 51.332386, 'longitude': 1.421525}}
# {'_id': ObjectId('65c944d0f5d232a221442a1f'),
#  'geocode': {'latitude': 51.349914, 'longitude': 1.440672}}
# {'_id': ObjectId('65c944d0f5d232a221442a20'),
#  'geocode': {'latitude': 51.332386, 'longitude': 1.421525}}
# {'_id': ObjectId('65c944d0f5d232a221442a21'),
#  'geocode': {'latitude': 51.332386, 'longitude': 1.421525}}
# {'_id': ObjectId('65c944d0f5d232a221442a22'),
#  'geocode': {'latitude': 51.332495, 'longitude': 1.421188}}
# {'_id': ObjectId('65c944d0f5d232a221442a23'),
#  'geocode': {'latitude': 51.335185, 'longitude': 1.423643}}
# {'_id': ObjectId('65c944d0f5d232a221442a24'),
#  'geocode': {'latitude': 51.33336, 'longitude': 1.422057}}
# {'_id': ObjectId('65c944d0f5d232a221442a25'),
#  'geocode': {'latitude': 51.343133, 'longitude': 1.432365}}
# {'_id': ObjectId('65c944d0f5d232a221442a26'),
#  'geocode': {'latitude': 51.343133, 'longitude': 1.432364}}
# {'_id': ObjectId('65c944d0f5d232a221442a27'),
#  'geocode': {'latitude': 51.074546, 'longitude': 1.152994}}
# {'_id': ObjectId('65c944d0f5d232a221442a28'),
#  'geocode': {'latitude': 51.077345, 'longitude': 1.155598}}
# {'_id': ObjectId('65c944d0f5d232a221442a29'),
#  'geocode': {'latitude': 51.334809, 'longitude': 1.422667}}
# {'_id': ObjectId('65c944d0f5d232a221442a2a'),
#  'geocode': {'latitude': 51.332386, 'longitude': 1.421525}}
# {'_id': ObjectId('65c944d0f5d232a221442a2b'),
#  'geocode': {'latitude': 51.33237, 'longitude': 1.420231}}
# {'_id': ObjectId('65c944d0f5d232a221442a2c'),
#  'geocode': {'latitude': 51.33237, 'longitude': 1.420231}}
# {'_id': ObjectId('65c944d0f5d232a221442a2d'),
#  'geocode': {'latitude': 51.335185, 'longitude': 1.423643}}
# {'_id': ObjectId('65c944d0f5d232a221442a2e'),
#  'geocode': {'latitude': 51.3330688476563, 'longitude': 1.42028105258942}}
# {'_id': ObjectId('65c944d0f5d232a221442a30'),
#  'geocode': {'latitude': 51.352901, 'longitude': 1.440982}}
# {'_id': ObjectId('65c944d0f5d232a221442a31'),
#  'geocode': {'latitude': 51.332515, 'longitude': 1.419581}}
# {'_id': ObjectId('65c944d0f5d232a221442a32'),
#  'geocode': {'latitude': 51.330413, 'longitude': 1.417328}}
# {'_id': ObjectId('65c944d0f5d232a221442a33'),
#  'geocode': {'latitude': 51.330413, 'longitude': 1.417328}}
# {'_id': ObjectId('65c944d0f5d232a221442a34'),
#  'geocode': {'latitude': 51.330413, 'longitude': 1.417328}}
# {'_id': ObjectId('65c944d0f5d232a221442a35'),
#  'geocode': {'latitude': 51.330413, 'longitude': 1.417328}}
# {'_id': ObjectId('65c944d0f5d232a221442a36'),
#  'geocode': {'latitude': 51.3310761, 'longitude': 1.4179475}}
# {'_id': ObjectId('65c944d0f5d232a221442a37'),
#  'geocode': {'latitude': 51.3332063, 'longitude': 1.4201594}}
# {'_id': ObjectId('65c944d0f5d232a221442a38'),
#  'geocode': {'latitude': 51.333009, 'longitude': 1.419934}}
# {'_id': ObjectId('65c944d0f5d232a221442a39'),
#  'geocode': {'latitude': 51.333009, 'longitude': 1.419934}}
# {'_id': ObjectId('65c944d0f5d232a221442a3a'),
#  'geocode': {'latitude': 51.333009, 'longitude': 1.419934}}
# {'_id': ObjectId('65c944d0f5d232a221442a3b'),
#  'geocode': {'latitude': 51.333009, 'longitude': 1.419934}}
# {'_id': ObjectId('65c944d0f5d232a221442a3c'),
#  'geocode': {'latitude': 51.333009, 'longitude': 1.419934}}
# {'_id': ObjectId('65c944d0f5d232a221442a3d'),
#  'geocode': {'latitude': 51.333009, 'longitude': 1.419934}}
# {'_id': ObjectId('65c944d0f5d232a221442a3e'),
#  'geocode': {'latitude': 51.333009, 'longitude': 1.419934}}
# {'_id': ObjectId('65c944d0f5d232a221442a3f'),
#  'geocode': {'latitude': 51.333918, 'longitude': 1.420835}}
# {'_id': ObjectId('65c944d0f5d232a221442a40'),
#  'geocode': {'latitude': 51.351811, 'longitude': 1.441044}}
# {'_id': ObjectId('65c944d0f5d232a221442a42'),
#  'geocode': {'latitude': 51.33875, 'longitude': 1.427211}}
# {'_id': ObjectId('65c944d0f5d232a221442a44'),
#  'geocode': {'latitude': 51.3322715759277, 'longitude': 1.41947197914124}}
# {'_id': ObjectId('65c944d0f5d232a221442a46'),
#  'geocode': {'latitude': 51.333152, 'longitude': 1.4198331}}
# {'_id': ObjectId('65c944d0f5d232a221442a47'),
#  'geocode': {'latitude': 51.086577, 'longitude': 1.163467}}
# {'_id': ObjectId('65c944d0f5d232a221442a48'),
#  'geocode': {'latitude': 51.3341272, 'longitude': 1.4206587}}
# {'_id': ObjectId('65c944d0f5d232a221442a49'),
#  'geocode': {'latitude': 51.0737868, 'longitude': 1.1503712}}
# {'_id': ObjectId('65c944d0f5d232a221442a4a'),
#  'geocode': {'latitude': 51.332812, 'longitude': 1.419273}}
# {'_id': ObjectId('65c944d0f5d232a221442a4b'),
#  'geocode': {'latitude': 51.332812, 'longitude': 1.419273}}
# {'_id': ObjectId('65c944d0f5d232a221442a4c'),
#  'geocode': {'latitude': 51.332812, 'longitude': 1.419273}}
# {'_id': ObjectId('65c944d0f5d232a221442a4d'),
#  'geocode': {'latitude': 51.332812, 'longitude': 1.419273}}
# {'_id': ObjectId('65c944d0f5d232a221442a4e'),
#  'geocode': {'latitude': 51.332812, 'longitude': 1.419273}}
# {'_id': ObjectId('65c944d0f5d232a221442a4f'),
#  'geocode': {'latitude': 51.331827, 'longitude': 1.418209}}
# {'_id': ObjectId('65c944d0f5d232a221442a50'),
#  'geocode': {'latitude': 51.3338775634766, 'longitude': 1.42038595676422}}
# {'_id': ObjectId('65c944d0f5d232a221442a51'),
#  'geocode': {'latitude': 51.331827, 'longitude': 1.418209}}
# {'_id': ObjectId('65c944d0f5d232a221442a52'),
#  'geocode': {'latitude': 51.332812, 'longitude': 1.419273}}
# {'_id': ObjectId('65c944d0f5d232a221442a53'),
#  'geocode': {'latitude': 51.332812, 'longitude': 1.419273}}
# {'_id': ObjectId('65c944d0f5d232a221442a54'),
#  'geocode': {'latitude': 51.33308, 'longitude': 1.42027}}
# {'_id': ObjectId('65c944d0f5d232a221442a55'),
#  'geocode': {'latitude': 51.3328557, 'longitude': 1.4192286}}
# {'_id': ObjectId('65c944d0f5d232a221442a56'),
#  'geocode': {'latitude': 51.332812, 'longitude': 1.419273}}
# {'_id': ObjectId('65c944d0f5d232a221442a57'),
#  'geocode': {'latitude': 51.3348208, 'longitude': 1.4212417}}
# {'_id': ObjectId('65c944d0f5d232a221442a59'),
#  'geocode': {'latitude': 51.3348734, 'longitude': 1.4212887}}
# {'_id': ObjectId('65c944d0f5d232a221442a5a'),
#  'geocode': {'latitude': 51.3319, 'longitude': 1.418171}}
# {'_id': ObjectId('65c944d0f5d232a221442a5c'),
#  'geocode': {'latitude': 51.3332961, 'longitude': 1.4195486}}
# {'_id': ObjectId('65c944d0f5d232a221442a5d'),
#  'geocode': {'latitude': 51.337357, 'longitude': 1.423776}}
# {'_id': ObjectId('65c944d0f5d232a221442a5e'),
#  'geocode': {'latitude': 51.3373565673828, 'longitude': 1.42377603054047}}
# {'_id': ObjectId('65c944d0f5d232a221442a5f'),
#  'geocode': {'latitude': 51.335788, 'longitude': 1.422094}}
# {'_id': ObjectId('65c944d0f5d232a221442a60'),
#  'geocode': {'latitude': 51.33811, 'longitude': 1.424507}}
# {'_id': ObjectId('65c944d0f5d232a221442a61'),
#  'geocode': {'latitude': 51.333075, 'longitude': 1.419207}}
# {'_id': ObjectId('65c944d0f5d232a221442a62'),
#  'geocode': {'latitude': 51.340005, 'longitude': 1.426473}}
# {'_id': ObjectId('65c944d0f5d232a221442a63'),
#  'geocode': {'latitude': 51.330249, 'longitude': 1.416168}}
# {'_id': ObjectId('65c944d0f5d232a221442a64'),
#  'geocode': {'latitude': 51.330249, 'longitude': 1.416168}}
# {'_id': ObjectId('65c944d0f5d232a221442a65'),
#  'geocode': {'latitude': 51.330249, 'longitude': 1.416168}}
# {'_id': ObjectId('65c944d0f5d232a221442a66'),
#  'geocode': {'latitude': 51.333174, 'longitude': 1.41917}}
# {'_id': ObjectId('65c944d0f5d232a221442a67'),
#  'geocode': {'latitude': 51.333159, 'longitude': 1.419098}}
# ...
#  'geocode': {'latitude': 51.7019041254121, 'longitude': 0.452177250455623}}
# {'_id': ObjectId('65c944d2f5d232a221448552'),
#  'geocode': {'latitude': 51.7019041254121, 'longitude': 0.452177250455623}}
# {'_id': ObjectId('65c944d2f5d232a221448553'),
#  'geocode': {'latitude': 51.7019041254121, 'longitude': 0.452177250455623}}
# {'_id': ObjectId('65c944d2f5d232a221448554'),
#  'geocode': {'latitude': 51.7019041254121, 'longitude': 0.452177250455623}}
# {'_id': ObjectId('65c944d2f5d232a221448555'),
#  'geocode': {'latitude': 51.7019041254121, 'longitude': 0.452177250455623}}
# {'_id': ObjectId('65c944d2f5d232a221448556'),
#  'geocode': {'latitude': 51.7019041254121, 'longitude': 0.452177250455623}}
# {'_id': ObjectId('65c944d2f5d232a221448557'),
#  'geocode': {'latitude': 51.433468, 'longitude': 0.178938}}
# {'_id': ObjectId('65c944d2f5d232a221448558'),
#  'geocode': {'latitude': 51.720513, 'longitude': 0.470894}}
# {'_id': ObjectId('65c944d2f5d232a221448559'),
#  'geocode': {'latitude': 51.44875, 'longitude': 0.194216}}
# {'_id': ObjectId('65c944d2f5d232a22144855a'),
#  'geocode': {'latitude': 51.7019041254121, 'longitude': 0.452177250455623}}
# {'_id': ObjectId('65c944d2f5d232a22144855b'),
#  'geocode': {'latitude': 51.720514, 'longitude': 0.470895}}
# {'_id': ObjectId('65c944d2f5d232a22144855c'),
#  'geocode': {'latitude': 51.740975000696, 'longitude': 0.491644998431379}}
# {'_id': ObjectId('65c944d2f5d232a22144855d'),
#  'geocode': {'latitude': 51.391472, 'longitude': 0.136349}}
# {'_id': ObjectId('65c944d2f5d232a22144855e'),
#  'geocode': {'latitude': 51.743156, 'longitude': 0.493527}}
# {'_id': ObjectId('65c944d2f5d232a22144855f'),
#  'geocode': {'latitude': 51.391472, 'longitude': 0.136349}}
# {'_id': ObjectId('65c944d2f5d232a221448560'),
#  'geocode': {'latitude': 51.739867, 'longitude': 0.490043}}
# {'_id': ObjectId('65c944d2f5d232a221448561'),
#  'geocode': {'latitude': 51.5998611450195, 'longitude': 0.346935987472534}}
# {'_id': ObjectId('65c944d2f5d232a221448562'),
#  'geocode': {'latitude': 51.747623, 'longitude': 0.497888}}
# {'_id': ObjectId('65c944d2f5d232a221448563'),
#  'geocode': {'latitude': 51.259635, 'longitude': 0.004087}}
# {'_id': ObjectId('65c944d2f5d232a221448564'),
#  'geocode': {'latitude': 51.747623, 'longitude': 0.497887}}
# {'_id': ObjectId('65c944d2f5d232a221448565'),
#  'geocode': {'latitude': 51.747623, 'longitude': 0.497888}}
# {'_id': ObjectId('65c944d2f5d232a221448566'),
#  'geocode': {'latitude': 51.7345657348633, 'longitude': 0.484234005212784}}
# {'_id': ObjectId('65c944d2f5d232a221448567'),
#  'geocode': {'latitude': 51.7345657348633, 'longitude': 0.484234005212784}}
# {'_id': ObjectId('65c944d2f5d232a221448568'),
#  'geocode': {'latitude': 51.734567, 'longitude': 0.484234}}
# {'_id': ObjectId('65c944d2f5d232a221448569'),
#  'geocode': {'latitude': 51.37375, 'longitude': 0.117807}}
# {'_id': ObjectId('65c944d2f5d232a22144856a'),
#  'geocode': {'latitude': 51.373751, 'longitude': 0.117807}}
# {'_id': ObjectId('65c944d2f5d232a22144856b'),
#  'geocode': {'latitude': 51.373751, 'longitude': 0.117807}}
# {'_id': ObjectId('65c944d2f5d232a22144856c'),
#  'geocode': {'latitude': 51.373751, 'longitude': 0.117807}}
# {'_id': ObjectId('65c944d2f5d232a22144856d'),
#  'geocode': {'latitude': 51.3737525939941, 'longitude': 0.117807000875473}}
# {'_id': ObjectId('65c944d2f5d232a22144856e'),
#  'geocode': {'latitude': 51.445624, 'longitude': 0.189706}}
# {'_id': ObjectId('65c944d2f5d232a22144856f'),
#  'geocode': {'latitude': 51.506429, 'longitude': 0.251242}}
# {'_id': ObjectId('65c944d2f5d232a221448570'),
#  'geocode': {'latitude': 51.445624, 'longitude': 0.189706}}
# {'_id': ObjectId('65c944d2f5d232a221448571'),
#  'geocode': {'latitude': 51.445624, 'longitude': 0.189706}}
# {'_id': ObjectId('65c944d2f5d232a221448572'),
#  'geocode': {'latitude': 51.372845, 'longitude': 0.116185}}
# {'_id': ObjectId('65c944d2f5d232a221448573'),
#  'geocode': {'latitude': 51.445624, 'longitude': 0.189706}}
# {'_id': ObjectId('65c944d2f5d232a221448574'),
#  'geocode': {'latitude': 51.714909, 'longitude': 0.463278}}
# {'_id': ObjectId('65c944d2f5d232a221448575'),
#  'geocode': {'latitude': 51.431155, 'longitude': 0.174656}}
# {'_id': ObjectId('65c944d2f5d232a221448576'),
#  'geocode': {'latitude': 51.431155, 'longitude': 0.174655}}
# {'_id': ObjectId('65c944d2f5d232a221448577'),
#  'geocode': {'latitude': 51.431155, 'longitude': 0.174655}}
# {'_id': ObjectId('65c944d2f5d232a221448578'),
#  'geocode': {'latitude': 51.7388300133164, 'longitude': 0.487564978785471}}
# {'_id': ObjectId('65c944d2f5d232a221448579'),
#  'geocode': {'latitude': 51.434232, 'longitude': 0.177521}}
# {'_id': ObjectId('65c944d2f5d232a22144857a'),
#  'geocode': {'latitude': 51.3727576, 'longitude': 0.1160476}}
# {'_id': ObjectId('65c944d2f5d232a22144857b'),
#  'geocode': {'latitude': 51.434232, 'longitude': 0.177521}}
# {'_id': ObjectId('65c944d2f5d232a22144857c'),
#  'geocode': {'latitude': 51.434232, 'longitude': 0.177521}}
# {'_id': ObjectId('65c944d2f5d232a22144857d'),
#  'geocode': {'latitude': 51.3741271, 'longitude': 0.116901}}
# {'_id': ObjectId('65c944d2f5d232a22144857e'),
#  'geocode': {'latitude': 51.7317023002796, 'longitude': 0.480005200686646}}
# {'_id': ObjectId('65c944d2f5d232a22144857f'),
#  'geocode': {'latitude': 51.738198, 'longitude': 0.48688}}
# {'_id': ObjectId('65c944d2f5d232a221448580'),
#  'geocode': {'latitude': 51.730758, 'longitude': 0.478927}}
# {'_id': ObjectId('65c944d2f5d232a221448581'),
#  'geocode': {'latitude': 51.933178, 'longitude': 0.688709}}
# {'_id': ObjectId('65c944d2f5d232a221448582'),
#  'geocode': {'latitude': 51.729401, 'longitude': 0.4774569}}
# {'_id': ObjectId('65c944d2f5d232a221448583'),
#  'geocode': {'latitude': 51.600688, 'longitude': 0.345622}}
# {'_id': ObjectId('65c944d2f5d232a221448584'),
#  'geocode': {'latitude': 51.748779296875, 'longitude': 0.497197985649109}}
# {'_id': ObjectId('65c944d2f5d232a221448585'),
#  'geocode': {'latitude': 51.600688, 'longitude': 0.345622}}
# {'_id': ObjectId('65c944d2f5d232a221448586'),
#  'geocode': {'latitude': 51.751615, 'longitude': 0.499615}}
# {'_id': ObjectId('65c944d2f5d232a221448587'),
#  'geocode': {'latitude': 51.448436, 'longitude': 0.191251}}
# {'_id': ObjectId('65c944d2f5d232a221448588'),
#  'geocode': {'latitude': 51.729594, 'longitude': 0.476995}}
# {'_id': ObjectId('65c944d2f5d232a221448589'),
#  'geocode': {'latitude': 51.89062, 'longitude': 0.643974}}
# {'_id': ObjectId('65c944d2f5d232a22144858a'),
#  'geocode': {'latitude': 51.29053, 'longitude': 0.032481}}
# {'_id': ObjectId('65c944d2f5d232a22144858b'),
#  'geocode': {'latitude': 51.508285, 'longitude': 0.251046}}
# {'_id': ObjectId('65c944d2f5d232a22144858c'),
#  'geocode': {'latitude': 51.363908, 'longitude': 0.105588}}
# {'_id': ObjectId('65c944d2f5d232a22144858d'),
#  'geocode': {'latitude': 51.572144, 'longitude': 0.315736}}
# {'_id': ObjectId('65c944d2f5d232a22144858e'),
#  'geocode': {'latitude': 51.737394, 'longitude': 0.48449}}
# {'_id': ObjectId('65c944d2f5d232a22144858f'),
#  'geocode': {'latitude': 51.730110168457, 'longitude': 0.47689300775528}}
# {'_id': ObjectId('65c944d2f5d232a221448590'),
#  'geocode': {'latitude': 51.424367, 'longitude': 0.165832}}
# {'_id': ObjectId('65c944d2f5d232a221448591'),
#  'geocode': {'latitude': 51.434532, 'longitude': 0.175867}}
# {'_id': ObjectId('65c944d2f5d232a221448592'),
#  'geocode': {'latitude': 51.3731, 'longitude': 0.113999}}
# {'_id': ObjectId('65c944d2f5d232a221448593'),
#  'geocode': {'latitude': 51.737394, 'longitude': 0.48449}}
# {'_id': ObjectId('65c944d2f5d232a221448594'),
#  'geocode': {'latitude': 51.551827, 'longitude': 0.294321}}
# {'_id': ObjectId('65c944d2f5d232a221448595'),
#  'geocode': {'latitude': 51.352605, 'longitude': 0.093508}}
# {'_id': ObjectId('65c944d2f5d232a221448596'),
#  'geocode': {'latitude': 51.7642250061035, 'longitude': 0.511412978172302}}
# {'_id': ObjectId('65c944d2f5d232a221448597'),
#  'geocode': {'latitude': 51.7351795, 'longitude': 0.4814955}}
# {'_id': ObjectId('65c944d2f5d232a221448598'),
#  'geocode': {'latitude': 51.73528, 'longitude': 0.481564}}
# {'_id': ObjectId('65c944d2f5d232a221448599'),
#  'geocode': {'latitude': 51.7528038024902, 'longitude': 0.499550014734268}}
# {'_id': ObjectId('65c944d2f5d232a22144859a'),
#  'geocode': {'latitude': 51.6566429138184, 'longitude': 0.400835990905762}}
# {'_id': ObjectId('65c944d2f5d232a22144859b'),
#  'geocode': {'latitude': 51.722301, 'longitude': 0.467981}}
# {'_id': ObjectId('65c944d2f5d232a22144859c'),
#  'geocode': {'latitude': 51.736026, 'longitude': 0.482025}}
# {'_id': ObjectId('65c944d2f5d232a22144859d'),
#  'geocode': {'latitude': 51.73528, 'longitude': 0.481564}}
# {'_id': ObjectId('65c944d2f5d232a22144859e'),
#  'geocode': {'latitude': 51.4266052246094, 'longitude': 0.166859000921249}}
# {'_id': ObjectId('65c944d2f5d232a22144859f'),
#  'geocode': {'latitude': 51.5087852478027, 'longitude': 0.24991700053215}}
# {'_id': ObjectId('65c944d2f5d232a2214485a0'),
#  'geocode': {'latitude': 51.72923, 'longitude': 0.475034}}
# {'_id': ObjectId('65c944d2f5d232a2214485a1'),
#  'geocode': {'latitude': 51.7359069, 'longitude': 0.4819699}}
# {'_id': ObjectId('65c944d2f5d232a2214485a2'),
#  'geocode': {'latitude': 51.426605, 'longitude': 0.166859}}
# {'_id': ObjectId('65c944d2f5d232a2214485a3'),
#  'geocode': {'latitude': 51.728273, 'longitude': 0.473954}}
# {'_id': ObjectId('65c944d2f5d232a2214485a4'),
#  'geocode': {'latitude': 51.4878959655762, 'longitude': 0.229052007198334}}
# {'_id': ObjectId('65c944d2f5d232a2214485a5'),
#  'geocode': {'latitude': 51.5094669, 'longitude': 0.2503952}}
# {'_id': ObjectId('65c944d2f5d232a2214485a6'),
#  'geocode': {'latitude': 51.733417, 'longitude': 0.478652}}
# {'_id': ObjectId('65c944d2f5d232a2214485a7'),
#  'geocode': {'latitude': 51.7363700866699, 'longitude': 0.481927990913391}}
# {'_id': ObjectId('65c944d2f5d232a2214485a8'),
#  'geocode': {'latitude': 51.751156, 'longitude': 0.497532}}
# {'_id': ObjectId('65c944d2f5d232a2214485a9'),
#  'geocode': {'latitude': 51.7515640258789, 'longitude': 0.497438997030258}}
# {'_id': ObjectId('65c944d2f5d232a2214485aa'),
#  'geocode': {'latitude': 51.733417, 'longitude': 0.478652}}
# {'_id': ObjectId('65c944d2f5d232a2214485ab'),
#  'geocode': {'latitude': 52.0247620984323, 'longitude': 0.781429023114024}}
# {'_id': ObjectId('65c944d2f5d232a2214485ac'),
#  'geocode': {'latitude': 51.7461624145508, 'longitude': 0.491737008094788}}
# {'_id': ObjectId('65c944d2f5d232a2214485ad'),
#  'geocode': {'latitude': 51.7333253, 'longitude': 0.478481}}
# {'_id': ObjectId('65c944d2f5d232a2214485ae'),
#  'geocode': {'latitude': 51.730921, 'longitude': 0.475923}}
# {'_id': ObjectId('65c944d2f5d232a2214485af'),
#  'geocode': {'latitude': 51.746162, 'longitude': 0.491737}}
# {'_id': ObjectId('65c944d2f5d232a2214485b0'),
#  'geocode': {'latitude': 51.73592, 'longitude': 0.481078}}
# {'_id': ObjectId('65c944d2f5d232a2214485b1'),
#  'geocode': {'latitude': 51.734173, 'longitude': 0.47907}}
# {'_id': ObjectId('65c944d2f5d232a2214485b2'),
#  'geocode': {'latitude': 52.0247620984323, 'longitude': 0.781429023114024}}
# {'_id': ObjectId('65c944d2f5d232a2214485b3'),
#  'geocode': {'latitude': 51.7325592041016, 'longitude': 0.477402001619339}}
# {'_id': ObjectId('65c944d2f5d232a2214485b4'),
#  'geocode': {'latitude': 51.7302889, 'longitude': 0.4750145}}
# {'_id': ObjectId('65c944d2f5d232a2214485b5'),
#  'geocode': {'latitude': 51.7303085327148, 'longitude': 0.474914014339447}}
# {'_id': ObjectId('65c944d2f5d232a2214485b6'),
#  'geocode': {'latitude': 51.3485069274902, 'longitude': 0.0878190025687218}}
# {'_id': ObjectId('65c944d2f5d232a2214485b7'),
#  'geocode': {'latitude': 51.5296612, 'longitude': 0.2702732}}
# {'_id': ObjectId('65c944d2f5d232a2214485b8'),
#  'geocode': {'latitude': 51.73224, 'longitude': 0.476908}}
# {'_id': ObjectId('65c944d2f5d232a2214485b9'),
#  'geocode': {'latitude': 51.731678, 'longitude': 0.476225}}
# {'_id': ObjectId('65c944d2f5d232a2214485ba'),
#  'geocode': {'latitude': 51.731678, 'longitude': 0.476225}}
# {'_id': ObjectId('65c944d2f5d232a2214485bb'),
#  'geocode': {'latitude': 51.731678, 'longitude': 0.476225}}
# {'_id': ObjectId('65c944d2f5d232a2214485bc'),
#  'geocode': {'latitude': 51.731678, 'longitude': 0.476225}}
# {'_id': ObjectId('65c944d2f5d232a2214485bd'),
#  'geocode': {'latitude': 51.731679, 'longitude': 0.476225}}
# {'_id': ObjectId('65c944d2f5d232a2214485be'),
#  'geocode': {'latitude': 51.7316599, 'longitude': 0.4761033}}
# {'_id': ObjectId('65c944d2f5d232a2214485bf'),
#  'geocode': {'latitude': 51.730701, 'longitude': 0.475201}}
# {'_id': ObjectId('65c944d2f5d232a2214485c0'),
#  'geocode': {'latitude': 51.731679, 'longitude': 0.476225}}
# {'_id': ObjectId('65c944d2f5d232a2214485c1'),
#  'geocode': {'latitude': 51.7316599, 'longitude': 0.4761033}}
# {'_id': ObjectId('65c944d2f5d232a2214485c2'),
#  'geocode': {'latitude': 51.7304371, 'longitude': 0.4748054}}
# {'_id': ObjectId('65c944d2f5d232a2214485c3'),
#  'geocode': {'latitude': 51.730433, 'longitude': 0.474709}}
# {'_id': ObjectId('65c944d2f5d232a2214485c4'),
#  'geocode': {'latitude': 51.7304344177246, 'longitude': 0.474709004163742}}
# {'_id': ObjectId('65c944d2f5d232a2214485c5'),
#  'geocode': {'latitude': 51.7304344177246, 'longitude': 0.474709004163742}}
# {'_id': ObjectId('65c944d2f5d232a2214485c6'),
#  'geocode': {'latitude': 51.7324663, 'longitude': 0.4766946}}
# {'_id': ObjectId('65c944d2f5d232a2214485c7'),
#  'geocode': {'latitude': 51.7316599, 'longitude': 0.4761033}}
# {'_id': ObjectId('65c944d2f5d232a2214485c8'),
#  'geocode': {'latitude': 51.743207, 'longitude': 0.487735}}
# {'_id': ObjectId('65c944d2f5d232a2214485c9'),
#  'geocode': {'latitude': 51.7303974, 'longitude': 0.474557}}
# {'_id': ObjectId('65c944d2f5d232a2214485ca'),
#  'geocode': {'latitude': 51.729576, 'longitude': 0.473576}}
# {'_id': ObjectId('65c944d2f5d232a2214485cb'),
#  'geocode': {'latitude': 51.730445, 'longitude': 0.474579}}
# {'_id': ObjectId('65c944d2f5d232a2214485cc'),
#  'geocode': {'latitude': 51.7318606, 'longitude': 0.4759695}}
# {'_id': ObjectId('65c944d2f5d232a2214485cd'),
#  'geocode': {'latitude': 51.729576, 'longitude': 0.473576}}
# {'_id': ObjectId('65c944d2f5d232a2214485ce'),
#  'geocode': {'latitude': 51.729576, 'longitude': 0.473576}}
# {'_id': ObjectId('65c944d2f5d232a2214485cf'),
#  'geocode': {'latitude': 51.730685, 'longitude': 0.474708}}
# {'_id': ObjectId('65c944d2f5d232a2214485d0'),
#  'geocode': {'latitude': 51.7305612, 'longitude': 0.4744646}}
# {'_id': ObjectId('65c944d2f5d232a2214485d1'),
#  'geocode': {'latitude': 51.730685, 'longitude': 0.474708}}
# {'_id': ObjectId('65c944d2f5d232a2214485d2'),
#  'geocode': {'latitude': 51.731972, 'longitude': 0.475981}}
# {'_id': ObjectId('65c944d2f5d232a2214485d3'),
#  'geocode': {'latitude': 51.73227296, 'longitude': 0.476289}}
# {'_id': ObjectId('65c944d2f5d232a2214485d4'),
#  'geocode': {'latitude': 51.731972, 'longitude': 0.475981}}
# {'_id': ObjectId('65c944d2f5d232a2214485d5'),
#  'geocode': {'latitude': 51.940436, 'longitude': 0.691835}}
# {'_id': ObjectId('65c944d2f5d232a2214485d6'),
#  'geocode': {'latitude': 51.733709, 'longitude': 0.477596}}
# {'_id': ObjectId('65c944d2f5d232a2214485d7'),
#  'geocode': {'latitude': 51.733709, 'longitude': 0.477596}}
# {'_id': ObjectId('65c944d2f5d232a2214485d8'),
#  'geocode': {'latitude': 51.733709, 'longitude': 0.477596}}
# {'_id': ObjectId('65c944d2f5d232a2214485d9'),
#  'geocode': {'latitude': 51.7307747, 'longitude': 0.4745777}}
# {'_id': ObjectId('65c944d2f5d232a2214485da'),
#  'geocode': {'latitude': 51.732944, 'longitude': 0.476729}}
# {'_id': ObjectId('65c944d2f5d232a2214485db'),
#  'geocode': {'latitude': 51.729795, 'longitude': 0.473399}}
# {'_id': ObjectId('65c944d2f5d232a2214485dc'),
#  'geocode': {'latitude': 51.7323994530968, 'longitude': 0.476139679135854}}
# {'_id': ObjectId('65c944d2f5d232a2214485dd'),
#  'geocode': {'latitude': 51.7323994530968, 'longitude': 0.476139679135854}}
# {'_id': ObjectId('65c944d2f5d232a2214485de'),
#  'geocode': {'latitude': 51.732944, 'longitude': 0.476729}}
# {'_id': ObjectId('65c944d2f5d232a2214485df'),
#  'geocode': {'latitude': 51.3513, 'longitude': 0.089485}}
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
